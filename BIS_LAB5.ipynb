# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakankshavr/BISLab/blob/main/BIS_LAB5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Define the objective function
def objective_function(x):
    # Example: Sphere function (minimize the sum of squares)
    return np.sum(x**2)

# Grey Wolf Optimizer (GWO)
def grey_wolf_optimizer(obj_function, dim, num_wolves, max_iter, bounds):
    # Initialize alpha, beta, delta
    alpha_pos = np.zeros(dim)
    alpha_score = float("inf")
    beta_pos = np.zeros(dim)
    beta_score = float("inf")
    delta_pos = np.zeros(dim)
    delta_score = float("inf")

    # Initialize the population (wolves' positions)
    wolves_pos = np.random.uniform(bounds[0], bounds[1], (num_wolves, dim))

    # Iterative optimization process
    for iteration in range(max_iter):
        # Evaluate fitness of each wolf
        for i, wolf in enumerate(wolves_pos):
            fitness = obj_function(wolf)

            # Update alpha, beta, and delta wolves
            if fitness < alpha_score:
                alpha_score, alpha_pos = fitness, wolf.copy()
            elif fitness < beta_score:
                beta_score, beta_pos = fitness, wolf.copy()
            elif fitness < delta_score:
                delta_score, delta_pos = fitness, wolf.copy()

        # Update wolves' positions
        for i in range(num_wolves):
            for j in range(dim):
                r1, r2 = np.random.random(), np.random.random()

                A1, C1 = 2 * r1 - 1, 2 * r2
                D_alpha = abs(C1 * alpha_pos[j] - wolves_pos[i, j])
                X1 = alpha_pos[j] - A1 * D_alpha

                r1, r2 = np.random.random(), np.random.random()
                A2, C2 = 2 * r1 - 1, 2 * r2
                D_beta = abs(C2 * beta_pos[j] - wolves_pos[i, j])
                X2 = beta_pos[j] - A2 * D_beta

                r1, r2 = np.random.random(), np.random.random()
                A3, C3 = 2 * r1 - 1, 2 * r2
                D_delta = abs(C3 * delta_pos[j] - wolves_pos[i, j])
                X3 = delta_pos[j] - A3 * D_delta

                # Update wolf position
                wolves_pos[i, j] = (X1 + X2 + X3) / 3

        # Constrain wolves' positions within bounds
        wolves_pos = np.clip(wolves_pos, bounds[0], bounds[1])

        # Track the progress
        print(f"Iteration {iteration + 1}, Best fitness: {alpha_score}")

    # Return the best solution (alpha wolf)
    return alpha_pos, alpha_score

# Example Usage
if __name__ == "__main__":
    dimension = 5  # Dimensionality of the problem
    num_wolves = 20  # Number of wolves
    max_iterations = 100  # Maximum number of iterations
    search_bounds = (-10, 10)  # Bounds of the search space

    best_position, best_fitness = grey_wolf_optimizer(
        objective_function, dimension, num_wolves, max_iterations, search_bounds
    )

    print("Best Position:", best_position)
    print("Best Fitness:", best_fitness)
# Out:
# Iteration 1, Best fitness: 78.79909607260159
# Iteration 2, Best fitness: 15.845582528825087
# Iteration 3, Best fitness: 6.726441101668141
# Iteration 4, Best fitness: 3.643232499468211
# Iteration 5, Best fitness: 2.706086868755083
# Iteration 6, Best fitness: 1.9103579229494505
# Iteration 7, Best fitness: 1.743403134024886
# Iteration 8, Best fitness: 1.2316880221719144
# Iteration 9, Best fitness: 0.9525135156362226
# Iteration 10, Best fitness: 0.7609013570263234
# Iteration 11, Best fitness: 0.3402080757730021
# Iteration 12, Best fitness: 0.24106259466101376
# Iteration 13, Best fitness: 0.21585203192687186
# Iteration 14, Best fitness: 0.17144495191676673
# Iteration 15, Best fitness: 0.14291736041364836
# Iteration 16, Best fitness: 0.14099731770258223
# Iteration 17, Best fitness: 0.10017504411647059
# Iteration 18, Best fitness: 0.05811151831701551
# Iteration 19, Best fitness: 0.05811151831701551
# Iteration 20, Best fitness: 0.042803806985577564
# Iteration 21, Best fitness: 0.0250929913063266
# Iteration 22, Best fitness: 0.018501443963966576
# Iteration 23, Best fitness: 0.01596790732141041
# Iteration 24, Best fitness: 0.01200691271842526
# Iteration 25, Best fitness: 0.009602606684306614
# Iteration 26, Best fitness: 0.006587553078231093
# Iteration 27, Best fitness: 0.004716193588918422
# Iteration 28, Best fitness: 0.0033180401551028997
# Iteration 29, Best fitness: 0.0024654339666114787
# Iteration 30, Best fitness: 0.0016594244925188738
# Iteration 31, Best fitness: 0.001287465099613955
# Iteration 32, Best fitness: 0.0009447014508883898
# Iteration 33, Best fitness: 0.0007641525381016465
# Iteration 34, Best fitness: 0.0005723809213843201
# Iteration 35, Best fitness: 0.0004454333781792161
# Iteration 36, Best fitness: 0.0003445864777118428
# Iteration 37, Best fitness: 0.00019329631445767962
# Iteration 38, Best fitness: 0.0001327902231147386
# Iteration 39, Best fitness: 0.00010819845199689805
# Iteration 40, Best fitness: 5.926423334414546e-05
# Iteration 41, Best fitness: 4.841932529819639e-05
# Iteration 42, Best fitness: 4.424775933478655e-05
# Iteration 43, Best fitness: 3.0660491156687886e-05
# Iteration 44, Best fitness: 1.925383631094233e-05
# Iteration 45, Best fitness: 1.46507386664551e-05
# Iteration 46, Best fitness: 1.048471900173023e-05
# Iteration 47, Best fitness: 9.076762291829847e-06
# Iteration 48, Best fitness: 5.697692175997392e-06
# Iteration 49, Best fitness: 4.855838343270955e-06
# Iteration 50, Best fitness: 3.1333299596525437e-06
# Iteration 51, Best fitness: 2.459604628412967e-06
# Iteration 52, Best fitness: 1.2020137264411283e-06
# Iteration 53, Best fitness: 1.1068259114507984e-06
# Iteration 54, Best fitness: 8.019760050437054e-07
# Iteration 55, Best fitness: 6.076634099705021e-07
# Iteration 56, Best fitness: 5.318478144121408e-07
# Iteration 57, Best fitness: 3.681704717507039e-07
# Iteration 58, Best fitness: 2.703898144771478e-07
# Iteration 59, Best fitness: 2.2959443038548298e-07
# Iteration 60, Best fitness: 1.9059800495061516e-07
# Iteration 61, Best fitness: 1.497481962362065e-07
# Iteration 62, Best fitness: 9.273657335798145e-08
# Iteration 63, Best fitness: 8.579066552253582e-08
# Iteration 64, Best fitness: 7.559302695366744e-08
# Iteration 65, Best fitness: 6.408101011716455e-08
# Iteration 66, Best fitness: 3.944691979266842e-08
# Iteration 67, Best fitness: 3.2487256420498397e-08
# Iteration 68, Best fitness: 2.670335790515516e-08
# Iteration 69, Best fitness: 1.707228954856048e-08
# Iteration 70, Best fitness: 1.21477374989546e-08
# Iteration 71, Best fitness: 1.0088567562805502e-08
# Iteration 72, Best fitness: 9.165629460127145e-09
# Iteration 73, Best fitness: 7.42052591313853e-09
# Iteration 74, Best fitness: 4.24657124224378e-09
# Iteration 75, Best fitness: 2.3194729286975277e-09
# Iteration 76, Best fitness: 2.0480646549252297e-09
# Iteration 77, Best fitness: 1.2143490101937522e-09
# Iteration 78, Best fitness: 1.0056137794805077e-09
# Iteration 79, Best fitness: 5.474952511614182e-10
# Iteration 80, Best fitness: 3.7231579332071396e-10
# Iteration 81, Best fitness: 2.930215351755614e-10
# Iteration 82, Best fitness: 2.316398530605296e-10
# Iteration 83, Best fitness: 1.6106317180505954e-10
# Iteration 84, Best fitness: 1.29712270263415e-10
# Iteration 85, Best fitness: 8.723719594310522e-11
# Iteration 86, Best fitness: 5.72435561244893e-11
# Iteration 87, Best fitness: 4.783313443695073e-11
# Iteration 88, Best fitness: 3.952422863740591e-11
# Iteration 89, Best fitness: 2.7943944344979405e-11
# Iteration 90, Best fitness: 1.56200367932841e-11
# Iteration 91, Best fitness: 1.1339290110059176e-11
# Iteration 92, Best fitness: 1.0355769599312622e-11
# Iteration 93, Best fitness: 6.616184505667709e-12
# Iteration 94, Best fitness: 5.426375373690683e-12
# Iteration 95, Best fitness: 2.3684568097457454e-12
# Iteration 96, Best fitness: 2.3684568097457454e-12
# Iteration 97, Best fitness: 1.6545607195713223e-12
# Iteration 98, Best fitness: 1.6545607195713223e-12
# Iteration 99, Best fitness: 1.1020033748058544e-12
# Iteration 100, Best fitness: 8.397451282662197e-13
# Best Position: [-1.97201241e-07 -4.62648881e-07 -4.67909704e-07  2.51207223e-07
#   5.52058197e-07]
# Best Fitness: 8.397451282662197e-13
