# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakankshavr/BISLab/blob/main/BIS_LAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Objective function to minimize: f(x) = x^2
def objective_function(x):
    return x**2

# Lévy flight step generator
def levy_flight(Lambda):
    """
    Generate a Lévy flight step with parameter Lambda.
    """
    sigma_u = (np.math.gamma(1 + Lambda) * np.sin(np.pi * Lambda / 2) /
               (np.math.gamma((1 + Lambda) / 2) * Lambda * 2**((Lambda - 1) / 2)))**(1 / Lambda)
    u = np.random.normal(0, sigma_u)
    v = np.random.normal(0, 1)
    step = u / (np.abs(v)**(1 / Lambda))
    return step

# Cuckoo Search parameters
num_nests = 25
discovery_rate = 0.25
iterations = 100
Lambda = 1.5  # Parameter for Lévy flights

# Initialize nests (1-dimensional problem)
nests = np.random.uniform(-10, 10, num_nests)
best_nest = nests[0]
best_fitness = objective_function(best_nest)

# Main loop
for iteration in range(iterations):
    # Generate new solutions using Lévy flight
    for i in range(num_nests):
        step_size = levy_flight(Lambda)
        new_solution = nests[i] + step_size * (nests[i] - best_nest)
        new_fitness = objective_function(new_solution)

        # If new solution is better, replace the current solution
        if new_fitness < objective_function(nests[i]):
            nests[i] = new_solution

        # Update best solution
        if new_fitness < best_fitness:
            best_fitness = new_fitness
            best_nest = new_solution

    # Abandon a fraction of worst nests
    num_abandoned = int(discovery_rate * num_nests)
    worst_indices = np.argsort([objective_function(nest) for nest in nests])[-num_abandoned:]
    nests[worst_indices] = np.random.uniform(-10, 10, num_abandoned)

    # Print best fitness for the current iteration
    print(f"Iteration {iteration + 1}: Best fitness = {best_fitness}")

# Final results
print("\nFinal best solution:", best_nest)
print("Final best fitness:", best_fitness)
# Out:
# Iteration 1: Best fitness = 0.3878649300663991
# Iteration 2: Best fitness = 0.001960036608227287
# Iteration 3: Best fitness = 0.0006913387967698774
# Iteration 4: Best fitness = 0.0006913387967698774
# Iteration 5: Best fitness = 0.0006913387967698774
# Iteration 6: Best fitness = 0.0006913387967698774
# Iteration 7: Best fitness = 8.75687878950942e-05
# Iteration 8: Best fitness = 1.6897231138258662e-06
# Iteration 9: Best fitness = 1.6897231138258662e-06
# Iteration 10: Best fitness = 1.6897231138258662e-06
# Iteration 11: Best fitness = 1.6897231138258662e-06
# Iteration 12: Best fitness = 1.6897231138258662e-06
# Iteration 13: Best fitness = 1.280811865271632e-06
# Iteration 14: Best fitness = 4.866355764685563e-07
# Iteration 15: Best fitness = 4.752934531883261e-07
# Iteration 16: Best fitness = 1.2852947706399044e-07
# Iteration 17: Best fitness = 4.503363803251578e-08
# Iteration 18: Best fitness = 9.922400867414966e-10
# Iteration 19: Best fitness = 9.922400867414966e-10
# Iteration 20: Best fitness = 9.922400867414966e-10
# Iteration 21: Best fitness = 9.922400867414966e-10
# Iteration 22: Best fitness = 9.922400867414966e-10
# Iteration 23: Best fitness = 9.922400867414966e-10
# Iteration 24: Best fitness = 6.320618922519212e-10
# Iteration 25: Best fitness = 2.644796662706245e-10
# Iteration 26: Best fitness = 2.644796662706245e-10
# Iteration 27: Best fitness = 2.644796662706245e-10
# Iteration 28: Best fitness = 9.777611051483191e-13
# Iteration 29: Best fitness = 9.777611051483191e-13
# Iteration 30: Best fitness = 9.777611051483191e-13
# Iteration 31: Best fitness = 9.777611051483191e-13
# Iteration 32: Best fitness = 9.777611051483191e-13
# Iteration 33: Best fitness = 9.777611051483191e-13
# Iteration 34: Best fitness = 9.777611051483191e-13
# Iteration 35: Best fitness = 9.777611051483191e-13
# Iteration 36: Best fitness = 3.989256937108009e-13
# Iteration 37: Best fitness = 1.8405760394754613e-13
# Iteration 38: Best fitness = 1.4275149314271344e-13
# Iteration 39: Best fitness = 1.4275149314271344e-13
# Iteration 40: Best fitness = 1.4275149314271344e-13
# Iteration 41: Best fitness = 5.597587247441269e-14
# Iteration 42: Best fitness = 1.2106946575167372e-19
# Iteration 43: Best fitness = 1.2106946575167372e-19
# Iteration 44: Best fitness = 1.2106946575167372e-19
# Iteration 45: Best fitness = 1.2106946575167372e-19
# Iteration 46: Best fitness = 1.2106946575167372e-19
# Iteration 47: Best fitness = 1.2106946575167372e-19
# Iteration 48: Best fitness = 1.2106946575167372e-19
# Iteration 49: Best fitness = 1.2106946575167372e-19
# Iteration 50: Best fitness = 1.2106946575167372e-19
# Iteration 51: Best fitness = 1.2106946575167372e-19
# Iteration 52: Best fitness = 1.2106946575167372e-19
# Iteration 53: Best fitness = 1.2106946575167372e-19
# Iteration 54: Best fitness = 1.2106946575167372e-19
# Iteration 55: Best fitness = 9.965669348491719e-20
# Iteration 56: Best fitness = 5.435751251132071e-20
# Iteration 57: Best fitness = 5.435751251132071e-20
# Iteration 58: Best fitness = 1.0279519506151698e-21
# Iteration 59: Best fitness = 9.685249498389488e-26
# Iteration 60: Best fitness = 9.685249498389488e-26
# Iteration 61: Best fitness = 9.685249498389488e-26
# Iteration 62: Best fitness = 9.685249498389488e-26
# Iteration 63: Best fitness = 9.685249498389488e-26
# Iteration 64: Best fitness = 1.4049841205315367e-26
# Iteration 65: Best fitness = 1.4049841205315367e-26
# Iteration 66: Best fitness = 1.4049841205315367e-26
# Iteration 67: Best fitness = 1.4049841205315367e-26
# Iteration 68: Best fitness = 6.558721411149247e-27
# Iteration 69: Best fitness = 6.558721411149247e-27
# Iteration 70: Best fitness = 3.0363968718455512e-27
# Iteration 71: Best fitness = 2.7484098389174074e-27
# Iteration 72: Best fitness = 2.7484098389174074e-27
# Iteration 73: Best fitness = 2.7484098389174074e-27
# Iteration 74: Best fitness = 2.6799771478145615e-27
# Iteration 75: Best fitness = 4.429315623103821e-29
# Iteration 76: Best fitness = 4.429315623103821e-29
# Iteration 77: Best fitness = 4.429315623103821e-29
# Iteration 78: Best fitness = 4.429315623103821e-29
# Iteration 79: Best fitness = 6.76266938066947e-30
# Iteration 80: Best fitness = 5.406258102231551e-30
# Iteration 81: Best fitness = 5.406258102231551e-30
# Iteration 82: Best fitness = 5.406258102231551e-30
# Iteration 83: Best fitness = 5.406258102231551e-30
# Iteration 84: Best fitness = 5.406258102231551e-30
# Iteration 85: Best fitness = 5.406258102231551e-30
# Iteration 86: Best fitness = 5.406258102231551e-30
# Iteration 87: Best fitness = 5.406258102231551e-30
# Iteration 88: Best fitness = 5.406258102231551e-30
# Iteration 89: Best fitness = 5.136581648806738e-30
# Iteration 90: Best fitness = 5.136581648806738e-30
# Iteration 91: Best fitness = 1.958655282351583e-30
# Iteration 92: Best fitness = 3.2537614240579794e-31
# Iteration 93: Best fitness = 3.2537614240579794e-31
# Iteration 94: Best fitness = 3.2537614240579794e-31
# Iteration 95: Best fitness = 2.3311946506434344e-32
# Iteration 96: Best fitness = 2.3311946506434344e-32
# Iteration 97: Best fitness = 6.889605533983416e-35
# Iteration 98: Best fitness = 6.889605533983416e-35
# Iteration 99: Best fitness = 6.889605533983416e-35
# Iteration 100: Best fitness = 6.889605533983416e-35
#
# Final best solution: 8.300364771492525e-18
# Final best fitness: 6.889605533983416e-35
# <ipython-input-3-c21a1b7fae49>:12: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   sigma_u = (np.math.gamma(1 + Lambda) * np.sin(np.pi * Lambda / 2) /
# <ipython-input-3-c21a1b7fae49>:13: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   (np.math.gamma((1 + Lambda) / 2) * Lambda * 2**((Lambda - 1) / 2)))**(1 / Lambda)
